# %% [markdown]
# #**Deep Learning Homework 2: *Optimize and Train Deep Models***
# ### MSc Computer Science, Data Science, Cybersecurity @UNIPD
# ### 2nd semester - 6 ECTS
# ### Prof. Alessandro Sperduti, Prof. Nicolò Navarin and Dr. Luca Pasa
# ---
# In this homework, we will explore how to develop a simple Deep Neural Network for a classification problem. We will learn how to use one of the most popular libraries for Deep Learning, namely [PyTorch 🔥](https://pytorch.org/). Then, we will see how to face a well known problem that is common during the training phase---overfitting on the training set. Finally, we will study how to perform a fair model selection.
#
# <u>Disclaimer</u>: PyTorch is a complex framework actively used by researcher and developers all over the word. It is highly customizable and there are many other packages build along it. The pourpouse of this and the next homeworks is not to go into all the details of its functionalities, but rather to give you an overview of its applications and understand its rationale. There are many good tutorials online and we suggest you to look at the official [Learn the Basics Tutorial](https://pytorch.org/tutorials/beginner/basics/intro.html), in particular if you are not familiar with other Deep Learning Frameworks.
#
# We hope that you will be able to use PyTorch by yourself for your future projects!
# ---
# ##**Important Instructions for Submissions:**
#
# Generally, in the homeworks, you will be either required to complete a part of Python code or to answer questions in text cells. Code and text cells where you are expected to write your answers have been marked by `%STARTCODE` and `%ENDCODE` or `%STARTEXT` and `%ENDTEXT` tags, respectively. Note that you should never change, move or remove these two tags, otherwise your answers will be __not__ valid. As you will see in this notebook, each cell that includes a `[TO COMPLETE]` part has been put between these placeholders.

# %% [markdown]
# ## Requirements

# %% [markdown]
# In this first exercise we will develop a deep feed forward neural network to perform text classification.
#
# Let's start importing the libraries we will need and setting a couple of environmental variables.

# %%
# They've just released torch 2.0, but we will use the more stable torch=1.13 along with other supporting libriaries
# !pip3 install datasets skorch pandas~=1.5 torch~=1.13 torchinfo torchdata~=0.5 torchtext~=0.14 torchvision~=0.14 torchaudio~=0.13
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 9.2 MB/s eta 0:00:00
# Collecting skorch
#   Downloading skorch-0.12.1-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.7/193.7 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas~=1.5 in /usr/local/lib/python3.9/dist-packages (1.5.3)
# Collecting torch~=1.13
#   Downloading torch-1.13.1-cp39-cp39-manylinux1_x86_64.whl (887.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 MB 1.6 MB/s eta 0:00:00
# Collecting torchinfo
#   Downloading torchinfo-1.7.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: torchdata~=0.5 in /usr/local/lib/python3.9/dist-packages (0.6.0)
# Requirement already satisfied: torchtext~=0.14 in /usr/local/lib/python3.9/dist-packages (0.15.1)
# Requirement already satisfied: torchvision~=0.14 in /usr/local/lib/python3.9/dist-packages (0.15.1+cu118)
# Collecting torchaudio~=0.13
#   Downloading torchaudio-0.13.1-cp39-cp39-manylinux1_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 74.2 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.27.1)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 11.8 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 76.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Collecting huggingface-hub<1.0.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 25.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.3.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 26.8 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 19.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.0)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.9/dist-packages (from skorch) (0.8.10)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from skorch) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.9/dist-packages (from skorch) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas~=1.5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas~=1.5) (2022.7.1)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 70.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.1 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 69.1 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch~=1.13) (4.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch~=1.13) (67.6.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch~=1.13) (0.40.0)
# Collecting torchdata~=0.5
#   Downloading torchdata-0.5.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 77.6 MB/s eta 0:00:00
# Collecting portalocker>=2.0.0
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.9/dist-packages (from torchdata~=0.5) (1.26.15)
# Collecting torchtext~=0.14
#   Downloading torchtext-0.14.1-cp39-cp39-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 79.4 MB/s eta 0:00:00
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision~=0.14) (8.4.0)
# Collecting torchvision~=0.14
#   Downloading torchvision-0.15.1-cp39-cp39-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 113.8 MB/s eta 0:00:00
#   Downloading torchvision-0.14.1-cp39-cp39-manylinux1_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 67.1 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 31.6 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 16.5 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 22.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas~=1.5) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.0->skorch) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.0->skorch) (1.2.0)
# Installing collected packages: xxhash, torchinfo, portalocker, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, multidict, frozenlist, dill, async-timeout, yarl, responses, nvidia-cudnn-cu11, multiprocess, huggingface-hub, aiosignal, torch, skorch, aiohttp, torchvision, torchtext, torchdata, torchaudio, datasets
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.1+cu118
#     Uninstalling torchvision-0.15.1+cu118:
#       Successfully uninstalled torchvision-0.15.1+cu118
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.15.1
#     Uninstalling torchtext-0.15.1:
#       Successfully uninstalled torchtext-0.15.1
#   Attempting uninstall: torchdata
#     Found existing installation: torchdata 0.6.0
#     Uninstalling torchdata-0.6.0:
#       Successfully uninstalled torchdata-0.6.0
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.0.1+cu118
#     Uninstalling torchaudio-2.0.1+cu118:
#       Successfully uninstalled torchaudio-2.0.1+cu118
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.11.0 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.13.4 multidict-6.0.4 multiprocess-0.70.14 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 portalocker-2.7.0 responses-0.18.0 skorch-0.12.1 torch-1.13.1 torchaudio-0.13.1 torchdata-0.5.1 torchinfo-1.7.2 torchtext-0.14.1 torchvision-0.14.1 xxhash-3.2.0 yarl-1.8.2

# %% [markdown]
# ##Imports

# %%
import torch
import torch.nn.functional as F
from torchinfo import summary
from torchtext.datasets import AG_NEWS
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch import nn
from sklearn.model_selection import GridSearchCV
from skorch import NeuralNetClassifier 
from skorch.helper import SliceDataset
import multiprocessing
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import logging
import os
from timeit import default_timer as timer

# %%
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" 

print(f"{torch.__version__=}")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"{device=}")
# !nvidia-smi --format=csv --query-gpu=index,name,driver_version,memory.total,memory.used,memory.free

# Set seed for reproducibility
torch.manual_seed(42)
rng = np.random.default_rng(seed=4242)
# Out:
# torch.__version__='1.13.1+cu117'
# device=device(type='cuda')
# index, name, driver_version, memory.total [MiB], memory.used [MiB], memory.free [MiB]
# 0, Tesla T4, 525.85.12, 15360 MiB, 3 MiB, 15098 MiB

# %% [markdown]
# #Data Loading and Preprocessing

# %% [markdown]
# ### Load Data: AG News Subset
#
# In this HW, we use the AG News Subset that is available in Torchtext Datasets. The AG's news topic classification dataset is constructed by choosing the 4 largest topic classes (1-World, 2-Sports, 3-Business, 4-Sci/Tech) from a larger news corpus. The total number of training samples is $120.000$ and testing $7.600$. For resource constraints, we will limit the number of training, validation and test samples to $10.000$, $1.000$ and $1.000$, respectively. Each sample contains both the title and an excerpt of the article, but in this exercise we will use only the excerpt as input.

# %%
train, test = AG_NEWS(root="dataset", split=('train', 'test'))
Tr, Ts = list(train), list(test)
rng.shuffle(Tr)
rng.shuffle(Ts)
len_train, len_val, len_test = 10000, 1000, 1000
train_data, val_data, test_data = Tr[:len_train], Ts[:len_val], Ts[len_val:len_val+len_test]

# %% [markdown]
# And have a look at one sample:

# %%
idx = 10
sample_label, sample_text = train_data[idx]
print(f"Text: {sample_text}")
print(f"Label: {sample_label}")
# Out:
# Text: Vancouver man is victim of shoddy FBI investigation: lawyer (Canadian Press) Canadian Press - VANCOUVER (CP) - A Vancouver man wanted by the U.S. for the 30-year-old murder of an American Indian Movement activist is being persecuted based on a faulty FBI investigation and the word of a troubled drug addict, says the lawyer defending his so-called partner in crime.
# Label: 1

# %% [markdown]
# ### Data Preprocessing
# We will go though the basic data processing building blocks for raw text string.
# Given a string, the first step is to tokenize the data to prepare it as input for the model. For this purpouse, we will use the basic Tokenizer of PyTorch. As you can see, it just normalizes the text, removes whitespaces and unsupported characters, and outputs a list:

# %%
tokenizer = get_tokenizer('basic_english')
print("Example: ", tokenizer("I am so HAPPY to study Deep Learning! #UNIPD #UniLIFE"))
# Out:
# Example:  ['i', 'am', 'so', 'happy', 'to', 'study', 'deep', 'learning', '!', '#unipd', '#unilife']

# %% [markdown]
# The AG News Subset dataset consists in news headlines---sequences of words. We have to encode each sample in a single tensor with a fixed number of elements, we will build a vocabulary of the headlines in our training set. In other words, we tokenize all the training set, and map each unique word into a number (a.k.a. index). This is necesseray as Neural Networks process numbers, so such vocabulary simply translates between readable words and numbers.

# %%
def create_tokens(dataset):
  for sample in dataset:
    yield tokenizer(sample[1])

# We limit our model to learn from the first 1000 most frequent tokens
vocab = build_vocab_from_iterator(create_tokens(train_data), specials=["<unk>"], max_tokens=1000) # <unk> is the index we use for specials characters ...
vocab.set_default_index(vocab["<unk>"]) # ... and as 0 the default values for tokens out of the vocabulary (OOV)
print(f"Our vocabulary is made of {len(vocab)} tokens-index pairs.")
# Out:
# Our vocabulary is made of 1000 tokens-index pairs.

# %% [markdown]
# This vocabulary was build from the training set. Let us see what it does on our example:

# %%
# Let us define some useful functions to handle tokens and labels
text_pipeline = lambda x: vocab(tokenizer(x)) # function to go from string -> tokens
label_pipeline = lambda x: int(x) - 1 # function to label starting form 0 for indexing

# %%
sample_tokenization = text_pipeline(sample_text)
sample_label_idx = label_pipeline(sample_label)
print(f"Samlpe headline text:\n {sample_text}")
print(f"Sample headline to tokens:\n {sample_tokenization}")
print(f"Label:\n {sample_label}")
print(f"Label index:\n {sample_label_idx}")
# Out:
# Samlpe headline text:
#  Vancouver man is victim of shoddy FBI investigation: lawyer (Canadian Press) Canadian Press - VANCOUVER (CP) - A Vancouver man wanted by the U.S. for the 30-year-old murder of an American Indian Movement activist is being persecuted based on a faulty FBI investigation and the word of a troubled drug addict, says the lawyer defending his so-called partner in crime.
# Sample headline to tokens:
#  [0, 415, 23, 0, 6, 0, 0, 963, 0, 13, 313, 262, 14, 313, 262, 15, 0, 13, 780, 14, 15, 5, 0, 415, 0, 24, 2, 51, 1, 9, 1, 11, 2, 0, 0, 6, 31, 159, 637, 0, 0, 23, 264, 0, 0, 10, 5, 0, 0, 963, 8, 2, 0, 6, 5, 0, 380, 0, 3, 82, 2, 0, 0, 34, 0, 0, 7, 0, 1]
# Label:
#  1
# Label index:
#  0

# %% [markdown]
# So each word is correctly mapped into a number, where most frequent words come first (see that the preposition "of", which is very frequent, gets translated to the number $6$). Notice also how "Vancouver" takes the default index value of $0$, meaning that is not frequent in the training set.
#
# Neural Netowrks (usually) take input of fixed size, but news aricles have different lenghts! To tackle this issue, one way is to resort to _multi-hot-encoding_ our dataset, means turning it into a tensor of $0$ and $1$. Concretely, this would mean for instance turning the sequence `[3, 5]` into a $1000$-dimensional vector (our vocabulary) that would be all zeros except for indices 3 and 5, which would be ones. The obtained input representation indicates which words are present (at least one time) in the sentence.

# %%
def multi_hot(token_list, n_cat=len(vocab)):
  encoded = [1 if i in token_list else 0 for i in range(n_cat)]
  return encoded

# %% [markdown]
# The next step is building a PyTorch `DataLoader`. Without going too much into the details, a `DataLoader` is the object one uses in the `for` loops when iterating over the data for training or inference. It has some additional benefits and pourpouses over iterating usual lists, such as multiprocessing, data transformation, sampling or shuffling. Don't worry too much for now, as we do this part for you.

# %%
class AGNewsDataset(Dataset):
  def __init__(self, dataset):
    super().__init__()
    self.dataset = dataset
  def __len__(self):
    return len(self.dataset)
  def __getitem__(self, idx):
    label, text = self.dataset[idx]
    lb = label_pipeline(label)
    txt = multi_hot(text_pipeline(text))
    lb, txt = torch.tensor(lb, dtype=torch.uint8, device=device), torch.tensor(txt, dtype=torch.float32, device=device)
    return lb, txt

# %%
train_dataset = AGNewsDataset(train_data)
val_dataset = AGNewsDataset(val_data)
test_dataset = AGNewsDataset(test_data)

# %%
batch_size = 256
dataloader_training = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
dataloader_validation = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
dataloader_test = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Exercise 2.1: Model Definition and Training
# We can now define the 3-layers feed forward model!
# In PyTorch we do that by subclassing `nn.Module`, and initialize the neural network layers in `__init__`. Every `nn.Module` subclass implements the operations on input data in the `forward` method.
#
# In detail, we created a `FeedforwardNetwork` class. The constructor takes three arguments: `input_dim` (an integer), which is the dimension of the input layer; `num_classes` (an integer), which is the number of output classes; and `hidden_layers_dim` (a list of integers), which is the dimension of the hidden layers in the network.
#
# In the constructor, the `nn.ModuleList() ` object is initialized to hold the layers of the network. If `hidden_layers_dim` is an empty list, then the network only consists of a single linear layer (from input to output). Otherwise, the network consists of multiple linear layers. The first layer goes from the input layer to the first hidden layer, and the subsequent hidden layers go from the previous hidden layer to the next hidden layer. The final output layer goes from the last hidden layer to the output layer.
#
# The `_init_weights` function is a helper function that initializes the weights of the linear layers in the network. It initializes the weights using a normal distribution with a mean of 0 and a standard deviation of 0.1, and sets the biases to zero. Notice that there exist other methods available in the `torch.nn.init` module to initialize layers' weights.
#
# The `forward` function defines the forward pass of the network. It first checks whether the network has only one layer (in which case it simply returns the output of that layer). Otherwise, it applies the `relu` activation function to the output of each hidden layer and passes the result to the next layer. Finally, it returns the output of the final layer. We don't apply the softmax function to the logits produced by the network as this will be done internally in the `CrossEntropyLoss` class, as documented [here](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html#torch.nn.CrossEntropyLoss).

# %%
class FeedforwardNetwork(nn.Module):
  
  def __init__(self, input_dim, num_classes, hidden_layers_dim=[]):
    super().__init__()
    self.layers = nn.ModuleList()
    if len(hidden_layers_dim) == 0:
      self.layers = self.layers.append(nn.Linear(input_dim, num_classes))
    else:
      for layer_idx in range(len(hidden_layers_dim)):
        if layer_idx == 0:  # first layer, from input to hidden
          self.layers = self.layers.append(nn.Linear(input_dim, hidden_layers_dim[layer_idx]))
        else:  # hidden layers, depending on the input
          self.layers = self.layers.append(nn.Linear(hidden_layers_dim[layer_idx-1], hidden_layers_dim[layer_idx]))
      self.layers = self.layers.append(nn.Linear(hidden_layers_dim[-1], num_classes))  # final output layer
    self.apply(self._init_weights)
    
  def _init_weights(self, module):
    if isinstance(module, nn.Linear):
        module.weight.data.normal_(mean=0.0, std=.1)
        if module.bias is not None:
            module.bias.data.zero_()
  
  def forward(self, x):
    if len(self.layers) == 1:
      return self.layers[0](x)
    else:
      for layer in self.layers[:-1]:
        x = F.relu(layer(x))
    return self.layers[-1](x)

# %%
# Now we prepare our model for this specific dataset and exercise
num_class = len(set([label for (label, text) in train_data]))
vocab_size = len(vocab)
EPOCHS = 40
lr = 1e-4
model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[64, 64]).to(device)
summary(model, (batch_size, vocab_size)) # Here is a nice summary of our model!
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# FeedforwardNetwork                       [256, 4]                  --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [256, 64]                 64,064
# │    └─Linear: 2-2                       [256, 64]                 4,160
# │    └─Linear: 2-3                       [256, 4]                  260
# ==========================================================================================
# Total params: 68,484
# Trainable params: 68,484
# Non-trainable params: 0
# Total mult-adds (M): 17.53
# ==========================================================================================
# Input size (MB): 1.02
# Forward/backward pass size (MB): 0.27
# Params size (MB): 0.27
# Estimated Total Size (MB): 1.57
# ==========================================================================================

# %%
# We need to defin our loss function (Cross Entropy for multiclass classification) and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# Finally, we can define the training procedure. In PyTorch there are few guidelines to follow to train a model. This time try on your own to understand what each line of code is doing, it will be required for the following HWs and exercises!

# %%
def train(model, optimizer, dataloader_train, dataloader_val, EPOCHS=EPOCHS):
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(EPOCHS):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      total_loss_train += loss
      loss.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
  return loss_train, acc_train, loss_val, acc_val

# %% [markdown]
# Let's train it!

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train(model, optimizer, dataloader_training, dataloader_validation)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 28.64%, Loss: 1.37913513 ---------------- Val_Acc: 31.20%, Val_Loss: 1.37503576
# epoch: 2 -> Accuracy: 36.15%, Loss: 1.35842133 ---------------- Val_Acc: 37.60%, Val_Loss: 1.35475576
# epoch: 3 -> Accuracy: 43.21%, Loss: 1.33493888 ---------------- Val_Acc: 43.90%, Val_Loss: 1.32880688
# epoch: 4 -> Accuracy: 50.03%, Loss: 1.30309188 ---------------- Val_Acc: 51.20%, Val_Loss: 1.29239726
# epoch: 5 -> Accuracy: 55.87%, Loss: 1.25794160 ---------------- Val_Acc: 58.20%, Val_Loss: 1.24086499
# epoch: 6 -> Accuracy: 61.50%, Loss: 1.19568813 ---------------- Val_Acc: 63.90%, Val_Loss: 1.17141378
# epoch: 7 -> Accuracy: 66.12%, Loss: 1.11570477 ---------------- Val_Acc: 67.90%, Val_Loss: 1.08569670
# epoch: 8 -> Accuracy: 69.60%, Loss: 1.02212441 ---------------- Val_Acc: 71.50%, Val_Loss: 0.99064529
# epoch: 9 -> Accuracy: 72.73%, Loss: 0.92407846 ---------------- Val_Acc: 74.00%, Val_Loss: 0.89694917
# epoch: 10 -> Accuracy: 75.13%, Loss: 0.83106863 ---------------- Val_Acc: 76.30%, Val_Loss: 0.81376761
# epoch: 11 -> Accuracy: 77.04%, Loss: 0.75068587 ---------------- Val_Acc: 76.80%, Val_Loss: 0.74479467
# epoch: 12 -> Accuracy: 78.57%, Loss: 0.68470925 ---------------- Val_Acc: 77.80%, Val_Loss: 0.68973422
# epoch: 13 -> Accuracy: 79.98%, Loss: 0.63159096 ---------------- Val_Acc: 78.40%, Val_Loss: 0.64663410
# epoch: 14 -> Accuracy: 80.91%, Loss: 0.58883625 ---------------- Val_Acc: 79.30%, Val_Loss: 0.61304080
# epoch: 15 -> Accuracy: 81.83%, Loss: 0.55414236 ---------------- Val_Acc: 80.40%, Val_Loss: 0.58655113
# epoch: 16 -> Accuracy: 82.69%, Loss: 0.52551466 ---------------- Val_Acc: 80.70%, Val_Loss: 0.56524336
# epoch: 17 -> Accuracy: 83.39%, Loss: 0.50143409 ---------------- Val_Acc: 80.80%, Val_Loss: 0.54799080
# epoch: 18 -> Accuracy: 83.86%, Loss: 0.48084861 ---------------- Val_Acc: 81.00%, Val_Loss: 0.53393841
# epoch: 19 -> Accuracy: 84.46%, Loss: 0.46304965 ---------------- Val_Acc: 81.60%, Val_Loss: 0.52230698
# epoch: 20 -> Accuracy: 84.92%, Loss: 0.44744045 ---------------- Val_Acc: 82.20%, Val_Loss: 0.51253402
# epoch: 21 -> Accuracy: 85.32%, Loss: 0.43354765 ---------------- Val_Acc: 82.40%, Val_Loss: 0.50428164
# epoch: 22 -> Accuracy: 85.64%, Loss: 0.42106256 ---------------- Val_Acc: 82.60%, Val_Loss: 0.49730524
# epoch: 23 -> Accuracy: 86.00%, Loss: 0.40975380 ---------------- Val_Acc: 83.20%, Val_Loss: 0.49132779
# epoch: 24 -> Accuracy: 86.28%, Loss: 0.39941600 ---------------- Val_Acc: 83.30%, Val_Loss: 0.48617533
# epoch: 25 -> Accuracy: 86.61%, Loss: 0.38991123 ---------------- Val_Acc: 83.30%, Val_Loss: 0.48169667
# epoch: 26 -> Accuracy: 86.89%, Loss: 0.38111496 ---------------- Val_Acc: 83.70%, Val_Loss: 0.47779340
# epoch: 27 -> Accuracy: 87.18%, Loss: 0.37292975 ---------------- Val_Acc: 83.60%, Val_Loss: 0.47439647
# epoch: 28 -> Accuracy: 87.36%, Loss: 0.36526754 ---------------- Val_Acc: 83.40%, Val_Loss: 0.47145891
# epoch: 29 -> Accuracy: 87.59%, Loss: 0.35807091 ---------------- Val_Acc: 83.60%, Val_Loss: 0.46891040
# epoch: 30 -> Accuracy: 87.84%, Loss: 0.35127783 ---------------- Val_Acc: 83.70%, Val_Loss: 0.46671987
# epoch: 31 -> Accuracy: 88.06%, Loss: 0.34484786 ---------------- Val_Acc: 83.70%, Val_Loss: 0.46480390
# epoch: 32 -> Accuracy: 88.30%, Loss: 0.33873680 ---------------- Val_Acc: 83.90%, Val_Loss: 0.46315405
# epoch: 33 -> Accuracy: 88.51%, Loss: 0.33291170 ---------------- Val_Acc: 84.00%, Val_Loss: 0.46172655
# epoch: 34 -> Accuracy: 88.68%, Loss: 0.32734692 ---------------- Val_Acc: 84.00%, Val_Loss: 0.46047717
# epoch: 35 -> Accuracy: 88.77%, Loss: 0.32201678 ---------------- Val_Acc: 84.10%, Val_Loss: 0.45941666
# epoch: 36 -> Accuracy: 88.97%, Loss: 0.31690234 ---------------- Val_Acc: 84.50%, Val_Loss: 0.45856085
# epoch: 37 -> Accuracy: 89.13%, Loss: 0.31198615 ---------------- Val_Acc: 84.80%, Val_Loss: 0.45784882
# epoch: 38 -> Accuracy: 89.30%, Loss: 0.30725285 ---------------- Val_Acc: 84.60%, Val_Loss: 0.45727220
# epoch: 39 -> Accuracy: 89.49%, Loss: 0.30267859 ---------------- Val_Acc: 84.50%, Val_Loss: 0.45683849
# epoch: 40 -> Accuracy: 89.60%, Loss: 0.29826099 ---------------- Val_Acc: 84.50%, Val_Loss: 0.45652449
# Training time in second: 215.84763549499996

# %% [markdown]
# We can now plot these results:

# %%
def plot_learning_acc_and_loss(loss_tr, acc_tr, loss_val, acc_val):
    info = {'loss_training':loss_tr,'acc_trainig':acc_tr, 'loss_validation':loss_val, 'acc_validation':acc_val}
    df = pd.DataFrame(info)
    df.plot(figsize=(8, 10), subplots=[('acc_trainig', 'acc_validation'), ('loss_training','loss_validation')], grid=True)
    plt.xlabel("Epochs")
    plt.show()
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# ### [TO COMPLETE] Evaluate the model:
#
# Now, our model has been optimized on the training set, and as you can see the performance on the validation set in quite similar (so it does not overfit the training data). Let's now evaluate the performance of our model using the test set. By having a look at the previous code, compute the performances on the test set.

# %% [markdown]
# `%STARTCODE`

# %%
model.eval()
total_acc_test, total_count_test, n_batches_test, loss = 0, 0, 0, 0

with torch.no_grad():
    for idx, (label, text) in enumerate(dataloader_test):
        logits = model(text)
        loss1 = criterion(logits, label)
        loss += loss1
        total_acc_test += (logits.argmax(1) == label).sum().item()
        total_count_test += label.size(0)
        n_batches_test += 1
loss_test = loss / n_batches_test
accuracy_test = total_acc_test / total_count_test
#[TO COMPLETE]

print(f"Test Loss: {loss_test:.8f}", end=' ---------- ')
print(f"Test Accuracy: {100*accuracy_test:.4f}%")
# Out:
# Test Loss: 0.44434321 ---------- Test Accuracy: 84.3000%

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# Explain why it is important to use test and validation, and why it is important to evaluate the model on the test set instead of the validation set. Finally, explain what is the usefulness of the validation set. Insert the discussion in the next cell.

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# Answer: Actually, The use of test and validation sets is essential in evaluating a performance, as it prevents overfitting and underfitting. The validation set helps to tune hyperparameters, ensuring that the model generalizes well to unseen data, while the test set provides an unbiased estimate of the model's performance.It is crucial to evaluate the model on the test set instead of the validation set, as overfitting can occur when tuning hyperparameters on the validation set.Overall, the validation set serves as a tool for optimizing the model's performance, while the test set serves as a final evaluation of the model's ability to generalize to new, unseen data**[TO COMLPETE]**

# %% [markdown]
# `%ENDTEXT`

# %% [markdown]
# # Exercise 2.2: Overfiting
#
# A common problem that occurs when you train a deep neural network is overfittig. Overfitting occurs when you achieve a good fit of your model on the training data, while it does not generalize well on new, unseen data. In other words, the model learned patterns specific to the training data, which are irrelevant in other data.
# As we have seen in the previous exercise, our model does not much overfit the training data. In this exercise, we try to modify the training parameters in order to have a model that overfits.
# Overfitting can have many causes and usually is a combination of some of them, for instance: too many parameters/ layers, too few training samples, wrong learning rate (usualy too high), etc..

# %% [markdown]
# ## [TO COMPLETE] Overfitting Model
# In the next cell define a new model (similar to the previuos one) that overfits the training data; then plot the trend of the loss in training and validation set.

# %% [markdown]
# `%STARTCODE`

# %%
EPOCHS =50 #[TO COMPLETE]
lr = 0.001 #[TO COMPLETE]
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[512, 512, 512]).to(device)#[TO COMPLETE]
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       512,512
# │    └─Linear: 2-2                       262,656
# │    └─Linear: 2-3                       262,656
# │    └─Linear: 2-4                       2,052
# =================================================================
# Total params: 1,039,876
# Trainable params: 1,039,876
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train(overfit_model, optimizer, dataloader_training, dataloader_validation,EPOCHS=50)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 56.68%, Loss: 1.18135154 ---------------- Val_Acc: 76.10%, Val_Loss: 0.66857493
# epoch: 2 -> Accuracy: 86.11%, Loss: 0.39728221 ---------------- Val_Acc: 80.00%, Val_Loss: 0.55856878
# epoch: 3 -> Accuracy: 93.85%, Loss: 0.20464802 ---------------- Val_Acc: 81.30%, Val_Loss: 0.55428416
# epoch: 4 -> Accuracy: 98.05%, Loss: 0.09982177 ---------------- Val_Acc: 81.40%, Val_Loss: 0.58454418
# epoch: 5 -> Accuracy: 99.21%, Loss: 0.05801513 ---------------- Val_Acc: 81.00%, Val_Loss: 0.68927372
# epoch: 6 -> Accuracy: 98.41%, Loss: 0.06100109 ---------------- Val_Acc: 76.90%, Val_Loss: 0.99205321
# epoch: 7 -> Accuracy: 97.02%, Loss: 0.08646335 ---------------- Val_Acc: 80.00%, Val_Loss: 0.71682394
# epoch: 8 -> Accuracy: 96.86%, Loss: 0.08825496 ---------------- Val_Acc: 83.20%, Val_Loss: 0.66674864
# epoch: 9 -> Accuracy: 99.47%, Loss: 0.02491929 ---------------- Val_Acc: 82.00%, Val_Loss: 0.74160933
# epoch: 10 -> Accuracy: 99.92%, Loss: 0.00917307 ---------------- Val_Acc: 82.90%, Val_Loss: 0.74852848
# epoch: 11 -> Accuracy: 100.00%, Loss: 0.00226907 ---------------- Val_Acc: 83.10%, Val_Loss: 0.77610147
# epoch: 12 -> Accuracy: 100.00%, Loss: 0.00150744 ---------------- Val_Acc: 82.90%, Val_Loss: 0.80303729
# epoch: 13 -> Accuracy: 100.00%, Loss: 0.00116918 ---------------- Val_Acc: 83.10%, Val_Loss: 0.82487112
# epoch: 14 -> Accuracy: 100.00%, Loss: 0.00094857 ---------------- Val_Acc: 83.20%, Val_Loss: 0.84457129
# epoch: 15 -> Accuracy: 100.00%, Loss: 0.00079168 ---------------- Val_Acc: 83.30%, Val_Loss: 0.86228949
# epoch: 16 -> Accuracy: 100.00%, Loss: 0.00067458 ---------------- Val_Acc: 83.30%, Val_Loss: 0.87825423
# epoch: 17 -> Accuracy: 100.00%, Loss: 0.00058361 ---------------- Val_Acc: 83.40%, Val_Loss: 0.89289844
# epoch: 18 -> Accuracy: 100.00%, Loss: 0.00051077 ---------------- Val_Acc: 83.50%, Val_Loss: 0.90667516
# epoch: 19 -> Accuracy: 100.00%, Loss: 0.00045134 ---------------- Val_Acc: 83.50%, Val_Loss: 0.91963631
# epoch: 20 -> Accuracy: 100.00%, Loss: 0.00040186 ---------------- Val_Acc: 83.40%, Val_Loss: 0.93185961
# epoch: 21 -> Accuracy: 100.00%, Loss: 0.00036012 ---------------- Val_Acc: 83.20%, Val_Loss: 0.94356644
# epoch: 22 -> Accuracy: 100.00%, Loss: 0.00032421 ---------------- Val_Acc: 83.30%, Val_Loss: 0.95513999
# epoch: 23 -> Accuracy: 100.00%, Loss: 0.00029194 ---------------- Val_Acc: 83.30%, Val_Loss: 0.96765411
# epoch: 24 -> Accuracy: 100.00%, Loss: 0.00026264 ---------------- Val_Acc: 83.30%, Val_Loss: 0.98031396
# epoch: 25 -> Accuracy: 100.00%, Loss: 0.00023538 ---------------- Val_Acc: 83.30%, Val_Loss: 0.99418056
# epoch: 26 -> Accuracy: 100.00%, Loss: 0.00020952 ---------------- Val_Acc: 83.30%, Val_Loss: 1.00917232
# epoch: 27 -> Accuracy: 100.00%, Loss: 0.00018529 ---------------- Val_Acc: 83.20%, Val_Loss: 1.02497709
# epoch: 28 -> Accuracy: 100.00%, Loss: 0.00016320 ---------------- Val_Acc: 83.30%, Val_Loss: 1.04150212
# epoch: 29 -> Accuracy: 100.00%, Loss: 0.00014372 ---------------- Val_Acc: 83.10%, Val_Loss: 1.05789709
# epoch: 30 -> Accuracy: 100.00%, Loss: 0.00012704 ---------------- Val_Acc: 83.10%, Val_Loss: 1.07319713
# epoch: 31 -> Accuracy: 100.00%, Loss: 0.00011301 ---------------- Val_Acc: 83.00%, Val_Loss: 1.08810568
# epoch: 32 -> Accuracy: 100.00%, Loss: 0.00010103 ---------------- Val_Acc: 83.00%, Val_Loss: 1.10244584
# epoch: 33 -> Accuracy: 100.00%, Loss: 0.00009084 ---------------- Val_Acc: 83.10%, Val_Loss: 1.11615133
# epoch: 34 -> Accuracy: 100.00%, Loss: 0.00008217 ---------------- Val_Acc: 83.10%, Val_Loss: 1.12968218
# epoch: 35 -> Accuracy: 100.00%, Loss: 0.00007473 ---------------- Val_Acc: 83.10%, Val_Loss: 1.14273596
# epoch: 36 -> Accuracy: 100.00%, Loss: 0.00006828 ---------------- Val_Acc: 83.10%, Val_Loss: 1.15523696
# epoch: 37 -> Accuracy: 100.00%, Loss: 0.00006267 ---------------- Val_Acc: 83.00%, Val_Loss: 1.16739416
# epoch: 38 -> Accuracy: 100.00%, Loss: 0.00005775 ---------------- Val_Acc: 82.90%, Val_Loss: 1.17922616
# epoch: 39 -> Accuracy: 100.00%, Loss: 0.00005340 ---------------- Val_Acc: 82.90%, Val_Loss: 1.19049704
# epoch: 40 -> Accuracy: 100.00%, Loss: 0.00004953 ---------------- Val_Acc: 82.90%, Val_Loss: 1.20146286
# epoch: 41 -> Accuracy: 100.00%, Loss: 0.00004606 ---------------- Val_Acc: 82.90%, Val_Loss: 1.21211982
# epoch: 42 -> Accuracy: 100.00%, Loss: 0.00004294 ---------------- Val_Acc: 82.90%, Val_Loss: 1.22178686
# epoch: 43 -> Accuracy: 100.00%, Loss: 0.00004016 ---------------- Val_Acc: 82.90%, Val_Loss: 1.23198056
# epoch: 44 -> Accuracy: 100.00%, Loss: 0.00003761 ---------------- Val_Acc: 82.90%, Val_Loss: 1.24178505
# epoch: 45 -> Accuracy: 100.00%, Loss: 0.00003529 ---------------- Val_Acc: 82.90%, Val_Loss: 1.25092447
# epoch: 46 -> Accuracy: 100.00%, Loss: 0.00003318 ---------------- Val_Acc: 82.90%, Val_Loss: 1.26007318
# epoch: 47 -> Accuracy: 100.00%, Loss: 0.00003125 ---------------- Val_Acc: 83.00%, Val_Loss: 1.26883459
# epoch: 48 -> Accuracy: 100.00%, Loss: 0.00002946 ---------------- Val_Acc: 82.90%, Val_Loss: 1.27690184
# epoch: 49 -> Accuracy: 100.00%, Loss: 0.00002783 ---------------- Val_Acc: 82.90%, Val_Loss: 1.28521430
# epoch: 50 -> Accuracy: 100.00%, Loss: 0.00002632 ---------------- Val_Acc: 82.90%, Val_Loss: 1.29314601
# Training time in second: 273.1534062280001

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# # Exercise 2.3: $L^1$- and $L^2$-regularization
# One possible way to solve the overitting issue is by using regularization methods. The two most common regularization methods in Deep Learning are the L1-norm regularization and the L2-norm regularization. Both These techniques are based on limiting the capacity of models, by adding a parameter norm penalty to the objective function $\mathcal{J}$:
# $$
# \hat{\mathcal{J}}(\theta,\mathbf{X},\mathbf{y}) = \mathcal{J}(\theta,\mathbf{X},\mathbf{y}) + \lambda L^p(\theta)
# $$
# where $\lambda$ is a hyperparameter that weighs the relative contribution of the norm penalty $L^p$ on a lernable parameter vector $\theta$:
# $$
#  L^p(\theta)=||\theta||_p=\left(\sum_i |\theta_i|^p\right)^{1/p}
# $$

# %% [markdown]
# In the following blocks you should implement both the $L^1$ and $L^2$ regularization for the overfitting model.
#
# **Disclaimer**: you can implement norms either from scratch (i.e. using simple math operators) or using `torch.linalg` methods, but **not** using implementations embedded in Torch optimizers.

# %% [markdown]
# ### [TO COMPLETE] $L^1$ Regularization

# %% [markdown]
# `%STARTCODE`

# %%
def train_L1(model, optimizer, dataloader_train, dataloader_val, l1_lambda, EPOCHS=EPOCHS):
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(EPOCHS):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      ##########################################################
      #[TO COMPLETE]
      loss_with_l1 = loss + l1_lambda * sum([torch.norm(param, 1) for param  in model.parameters()])

      ##########################################################
      total_loss_train += loss
      loss_with_l1.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
  return loss_train, acc_train, loss_val, acc_val

# %%
EPOCHS = 40
lr = 1e-4
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[256, 128, 64]).to(device)
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       256,256
# │    └─Linear: 2-2                       32,896
# │    └─Linear: 2-3                       8,256
# │    └─Linear: 2-4                       260
# =================================================================
# Total params: 297,668
# Trainable params: 297,668
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train_L1(overfit_model, optimizer, dataloader_training, dataloader_validation, l1_lambda=0.001)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 28.06%, Loss: 1.39263570 ---------------- Val_Acc: 29.10%, Val_Loss: 1.37801516
# epoch: 2 -> Accuracy: 30.87%, Loss: 1.37050974 ---------------- Val_Acc: 32.40%, Val_Loss: 1.36437726
# epoch: 3 -> Accuracy: 34.26%, Loss: 1.35474563 ---------------- Val_Acc: 36.80%, Val_Loss: 1.34905410
# epoch: 4 -> Accuracy: 38.05%, Loss: 1.33605373 ---------------- Val_Acc: 40.80%, Val_Loss: 1.32878935
# epoch: 5 -> Accuracy: 42.07%, Loss: 1.31117857 ---------------- Val_Acc: 43.80%, Val_Loss: 1.30104017
# epoch: 6 -> Accuracy: 45.90%, Loss: 1.27793586 ---------------- Val_Acc: 49.10%, Val_Loss: 1.26476550
# epoch: 7 -> Accuracy: 49.78%, Loss: 1.23573101 ---------------- Val_Acc: 52.40%, Val_Loss: 1.22016215
# epoch: 8 -> Accuracy: 53.62%, Loss: 1.18468666 ---------------- Val_Acc: 56.20%, Val_Loss: 1.16716933
# epoch: 9 -> Accuracy: 56.91%, Loss: 1.12573731 ---------------- Val_Acc: 59.90%, Val_Loss: 1.10815430
# epoch: 10 -> Accuracy: 59.69%, Loss: 1.06237817 ---------------- Val_Acc: 62.60%, Val_Loss: 1.04608917
# epoch: 11 -> Accuracy: 62.94%, Loss: 0.99884027 ---------------- Val_Acc: 64.20%, Val_Loss: 0.98559314
# epoch: 12 -> Accuracy: 65.87%, Loss: 0.93907040 ---------------- Val_Acc: 66.70%, Val_Loss: 0.93037081
# epoch: 13 -> Accuracy: 68.21%, Loss: 0.88574469 ---------------- Val_Acc: 69.20%, Val_Loss: 0.88258266
# epoch: 14 -> Accuracy: 70.18%, Loss: 0.83916408 ---------------- Val_Acc: 70.80%, Val_Loss: 0.84137565
# epoch: 15 -> Accuracy: 71.84%, Loss: 0.79876274 ---------------- Val_Acc: 71.80%, Val_Loss: 0.80624449
# epoch: 16 -> Accuracy: 73.23%, Loss: 0.76399392 ---------------- Val_Acc: 72.80%, Val_Loss: 0.77649581
# epoch: 17 -> Accuracy: 74.35%, Loss: 0.73405403 ---------------- Val_Acc: 73.40%, Val_Loss: 0.75085020
# epoch: 18 -> Accuracy: 75.55%, Loss: 0.70801657 ---------------- Val_Acc: 73.90%, Val_Loss: 0.72849476
# epoch: 19 -> Accuracy: 76.18%, Loss: 0.68519205 ---------------- Val_Acc: 74.40%, Val_Loss: 0.70908672
# epoch: 20 -> Accuracy: 77.00%, Loss: 0.66521853 ---------------- Val_Acc: 75.50%, Val_Loss: 0.69221640
# epoch: 21 -> Accuracy: 77.66%, Loss: 0.64751643 ---------------- Val_Acc: 76.40%, Val_Loss: 0.67727810
# epoch: 22 -> Accuracy: 78.14%, Loss: 0.63169813 ---------------- Val_Acc: 76.90%, Val_Loss: 0.66401166
# epoch: 23 -> Accuracy: 78.66%, Loss: 0.61750412 ---------------- Val_Acc: 77.20%, Val_Loss: 0.65225685
# epoch: 24 -> Accuracy: 79.12%, Loss: 0.60471904 ---------------- Val_Acc: 77.60%, Val_Loss: 0.64170825
# epoch: 25 -> Accuracy: 79.44%, Loss: 0.59310484 ---------------- Val_Acc: 77.70%, Val_Loss: 0.63215125
# epoch: 26 -> Accuracy: 79.90%, Loss: 0.58254594 ---------------- Val_Acc: 77.80%, Val_Loss: 0.62358063
# epoch: 27 -> Accuracy: 80.36%, Loss: 0.57294440 ---------------- Val_Acc: 78.20%, Val_Loss: 0.61584413
# epoch: 28 -> Accuracy: 80.71%, Loss: 0.56420392 ---------------- Val_Acc: 78.20%, Val_Loss: 0.60872465
# epoch: 29 -> Accuracy: 81.15%, Loss: 0.55620831 ---------------- Val_Acc: 78.40%, Val_Loss: 0.60228515
# epoch: 30 -> Accuracy: 81.53%, Loss: 0.54881042 ---------------- Val_Acc: 78.90%, Val_Loss: 0.59636223
# epoch: 31 -> Accuracy: 81.83%, Loss: 0.54197544 ---------------- Val_Acc: 79.20%, Val_Loss: 0.59100223
# epoch: 32 -> Accuracy: 82.00%, Loss: 0.53562784 ---------------- Val_Acc: 79.50%, Val_Loss: 0.58601451
# epoch: 33 -> Accuracy: 82.25%, Loss: 0.52975053 ---------------- Val_Acc: 79.60%, Val_Loss: 0.58136737
# epoch: 34 -> Accuracy: 82.37%, Loss: 0.52426451 ---------------- Val_Acc: 79.50%, Val_Loss: 0.57715774
# epoch: 35 -> Accuracy: 82.59%, Loss: 0.51914519 ---------------- Val_Acc: 79.60%, Val_Loss: 0.57327271
# epoch: 36 -> Accuracy: 82.62%, Loss: 0.51437342 ---------------- Val_Acc: 79.70%, Val_Loss: 0.56974709
# epoch: 37 -> Accuracy: 82.77%, Loss: 0.50990081 ---------------- Val_Acc: 79.80%, Val_Loss: 0.56644726
# epoch: 38 -> Accuracy: 82.94%, Loss: 0.50570214 ---------------- Val_Acc: 79.90%, Val_Loss: 0.56335080
# epoch: 39 -> Accuracy: 83.08%, Loss: 0.50170773 ---------------- Val_Acc: 79.90%, Val_Loss: 0.56043446
# epoch: 40 -> Accuracy: 83.08%, Loss: 0.49793646 ---------------- Val_Acc: 80.10%, Val_Loss: 0.55774617
# Training time in second: 222.02922360900016

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# ### [TO COMPLETE] $L^2$ Regularization

# %% [markdown]
# `%STARTCODE`

# %%
def train_L2(model, optimizer, dataloader_train, dataloader_val, l2_lambda=0.001, EPOCHS=EPOCHS):
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(EPOCHS):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      ##########################################################
      #[TO COMPLETE]
      loss_with_l2 = loss + l2_lambda * sum(torch.sum(param ** 2) for param in model.parameters())
      ##########################################################
      total_loss_train += loss
      loss_with_l2.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
  return loss_train, acc_train, loss_val, acc_val

# %%
EPOCHS = 40
lr = 1e-4
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[256, 128, 64]).to(device)
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       256,256
# │    └─Linear: 2-2                       32,896
# │    └─Linear: 2-3                       8,256
# │    └─Linear: 2-4                       260
# =================================================================
# Total params: 297,668
# Trainable params: 297,668
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train_L2(overfit_model, optimizer, dataloader_training, dataloader_validation, l2_lambda=0.01)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 27.59%, Loss: 1.38597500 ---------------- Val_Acc: 31.10%, Val_Loss: 1.36958861
# epoch: 2 -> Accuracy: 33.54%, Loss: 1.36197960 ---------------- Val_Acc: 35.70%, Val_Loss: 1.35253644
# epoch: 3 -> Accuracy: 38.22%, Loss: 1.34386444 ---------------- Val_Acc: 41.50%, Val_Loss: 1.33380473
# epoch: 4 -> Accuracy: 42.53%, Loss: 1.32288957 ---------------- Val_Acc: 45.10%, Val_Loss: 1.31056988
# epoch: 5 -> Accuracy: 46.08%, Loss: 1.29637969 ---------------- Val_Acc: 48.90%, Val_Loss: 1.27981031
# epoch: 6 -> Accuracy: 49.38%, Loss: 1.26084197 ---------------- Val_Acc: 53.40%, Val_Loss: 1.23866451
# epoch: 7 -> Accuracy: 52.90%, Loss: 1.21359301 ---------------- Val_Acc: 57.00%, Val_Loss: 1.18541837
# epoch: 8 -> Accuracy: 56.62%, Loss: 1.15424633 ---------------- Val_Acc: 61.00%, Val_Loss: 1.12063730
# epoch: 9 -> Accuracy: 59.88%, Loss: 1.08424664 ---------------- Val_Acc: 64.30%, Val_Loss: 1.04846835
# epoch: 10 -> Accuracy: 63.29%, Loss: 1.00983274 ---------------- Val_Acc: 67.20%, Val_Loss: 0.97633100
# epoch: 11 -> Accuracy: 66.41%, Loss: 0.93878317 ---------------- Val_Acc: 69.70%, Val_Loss: 0.91095710
# epoch: 12 -> Accuracy: 69.42%, Loss: 0.87466556 ---------------- Val_Acc: 72.10%, Val_Loss: 0.85468131
# epoch: 13 -> Accuracy: 71.80%, Loss: 0.81882316 ---------------- Val_Acc: 73.70%, Val_Loss: 0.80742115
# epoch: 14 -> Accuracy: 73.82%, Loss: 0.77109563 ---------------- Val_Acc: 74.80%, Val_Loss: 0.76778907
# epoch: 15 -> Accuracy: 75.53%, Loss: 0.73017806 ---------------- Val_Acc: 75.60%, Val_Loss: 0.73425949
# epoch: 16 -> Accuracy: 76.68%, Loss: 0.69475168 ---------------- Val_Acc: 76.30%, Val_Loss: 0.70537311
# epoch: 17 -> Accuracy: 78.01%, Loss: 0.66338438 ---------------- Val_Acc: 77.20%, Val_Loss: 0.68015581
# epoch: 18 -> Accuracy: 79.25%, Loss: 0.63560557 ---------------- Val_Acc: 77.80%, Val_Loss: 0.65810966
# epoch: 19 -> Accuracy: 80.24%, Loss: 0.61092877 ---------------- Val_Acc: 78.50%, Val_Loss: 0.63882560
# epoch: 20 -> Accuracy: 81.02%, Loss: 0.58901852 ---------------- Val_Acc: 79.20%, Val_Loss: 0.62186646
# epoch: 21 -> Accuracy: 81.80%, Loss: 0.56942588 ---------------- Val_Acc: 79.60%, Val_Loss: 0.60696459
# epoch: 22 -> Accuracy: 82.50%, Loss: 0.55194360 ---------------- Val_Acc: 79.90%, Val_Loss: 0.59392232
# epoch: 23 -> Accuracy: 83.16%, Loss: 0.53627068 ---------------- Val_Acc: 80.20%, Val_Loss: 0.58241105
# epoch: 24 -> Accuracy: 83.55%, Loss: 0.52219748 ---------------- Val_Acc: 80.50%, Val_Loss: 0.57231128
# epoch: 25 -> Accuracy: 84.18%, Loss: 0.50958771 ---------------- Val_Acc: 81.10%, Val_Loss: 0.56350374
# epoch: 26 -> Accuracy: 84.61%, Loss: 0.49825960 ---------------- Val_Acc: 81.60%, Val_Loss: 0.55562425
# epoch: 27 -> Accuracy: 84.91%, Loss: 0.48802087 ---------------- Val_Acc: 82.00%, Val_Loss: 0.54871804
# epoch: 28 -> Accuracy: 85.29%, Loss: 0.47878155 ---------------- Val_Acc: 82.00%, Val_Loss: 0.54271013
# epoch: 29 -> Accuracy: 85.51%, Loss: 0.47043177 ---------------- Val_Acc: 82.30%, Val_Loss: 0.53730774
# epoch: 30 -> Accuracy: 85.72%, Loss: 0.46280941 ---------------- Val_Acc: 82.50%, Val_Loss: 0.53244853
# epoch: 31 -> Accuracy: 85.90%, Loss: 0.45585942 ---------------- Val_Acc: 82.60%, Val_Loss: 0.52810931
# epoch: 32 -> Accuracy: 86.17%, Loss: 0.44950438 ---------------- Val_Acc: 82.50%, Val_Loss: 0.52412397
# epoch: 33 -> Accuracy: 86.30%, Loss: 0.44365174 ---------------- Val_Acc: 82.70%, Val_Loss: 0.52049631
# epoch: 34 -> Accuracy: 86.42%, Loss: 0.43826699 ---------------- Val_Acc: 82.80%, Val_Loss: 0.51722169
# epoch: 35 -> Accuracy: 86.64%, Loss: 0.43335572 ---------------- Val_Acc: 83.10%, Val_Loss: 0.51428372
# epoch: 36 -> Accuracy: 86.79%, Loss: 0.42882928 ---------------- Val_Acc: 83.10%, Val_Loss: 0.51155800
# epoch: 37 -> Accuracy: 87.00%, Loss: 0.42462873 ---------------- Val_Acc: 83.00%, Val_Loss: 0.50910950
# epoch: 38 -> Accuracy: 87.11%, Loss: 0.42075545 ---------------- Val_Acc: 83.20%, Val_Loss: 0.50681126
# epoch: 39 -> Accuracy: 87.24%, Loss: 0.41716075 ---------------- Val_Acc: 83.30%, Val_Loss: 0.50466120
# epoch: 40 -> Accuracy: 87.28%, Loss: 0.41380629 ---------------- Val_Acc: 83.50%, Val_Loss: 0.50268310
# Training time in second: 222.02891752900018

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# # Exercise 2.4: Early Stopping
# Early Stopping is a form of regularization used to avoid overfitting. It is designed to monitor the generalization error of one model and stop training when generalization error begins to degrade. In order to evaluate the generalization error, early stopping requires that a validation dataset is evaluated during training. Then, when the validation error does not improve for a specific number of epochs (a.k.a. the "patience" or "tolerance" hyper-parameter), it stops the training phase.
#
# To implement it in PyTorch, we define a simple classes that does this job.

# %%
class EarlyStopping:
    def __init__(self, tolerance, min_delta):
        self.tolerance = tolerance
        self.min_delta = min_delta
        self.counter = 0
        self.early_stop = False

    def __call__(self, train_loss, validation_loss):
        if (validation_loss - train_loss) > self.min_delta:
            self.counter +=1
            if self.counter >= self.tolerance:  
                self.early_stop = True

# %% [markdown]
# ## **[TO COMPLETE]**: Define training procedure
# Define a training procedure with Early Stopping and check its performances.

# %% [markdown]
# `%STARTCODE`

# %%
def train_early_stop(model, optimizer, dataloader_train, dataloader_val, EPOCHS=EPOCHS):
  ###########################################################
  # instantiate an object of the EarlyStopping class 
  early_stopping = EarlyStopping(tolerance=2, min_delta= 0.001)
  #[TO COMPLETE]
  ###########################################################
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(EPOCHS):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      total_loss_train += loss
      loss.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
    ############################################################
    # Use the EarlyStopping object
      if early_stopping(avg_loss_train, avg_loss_val):
        print(f"Training stopped early. Epoch: {epoch}")
        break
    #[TO COMPLETE]
    ############################################################
  return loss_train, acc_train, loss_val, acc_val

# %%
EPOCHS = 40
lr = 1e-4
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[256, 128, 64]).to(device)
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       256,256
# │    └─Linear: 2-2                       32,896
# │    └─Linear: 2-3                       8,256
# │    └─Linear: 2-4                       260
# =================================================================
# Total params: 297,668
# Trainable params: 297,668
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train_early_stop(overfit_model, optimizer, dataloader_training, dataloader_validation)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 30.37%, Loss: 1.36847723 ---------------- Val_Acc: 39.30%, Val_Loss: 1.33265483
# epoch: 2 -> Accuracy: 44.85%, Loss: 1.29705334 ---------------- Val_Acc: 50.40%, Val_Loss: 1.26206338
# epoch: 3 -> Accuracy: 56.26%, Loss: 1.20455801 ---------------- Val_Acc: 60.80%, Val_Loss: 1.15593135
# epoch: 4 -> Accuracy: 64.77%, Loss: 1.07078874 ---------------- Val_Acc: 68.40%, Val_Loss: 1.01120186
# epoch: 5 -> Accuracy: 71.59%, Loss: 0.90812552 ---------------- Val_Acc: 72.00%, Val_Loss: 0.85829550
# epoch: 6 -> Accuracy: 75.81%, Loss: 0.75582016 ---------------- Val_Acc: 75.40%, Val_Loss: 0.73660266
# epoch: 7 -> Accuracy: 79.13%, Loss: 0.64043182 ---------------- Val_Acc: 77.10%, Val_Loss: 0.65669525
# epoch: 8 -> Accuracy: 81.48%, Loss: 0.56063884 ---------------- Val_Acc: 78.60%, Val_Loss: 0.60644263
# epoch: 9 -> Accuracy: 82.97%, Loss: 0.50455266 ---------------- Val_Acc: 79.80%, Val_Loss: 0.57341766
# epoch: 10 -> Accuracy: 84.13%, Loss: 0.46257612 ---------------- Val_Acc: 80.70%, Val_Loss: 0.55080295
# epoch: 11 -> Accuracy: 85.08%, Loss: 0.42925236 ---------------- Val_Acc: 81.20%, Val_Loss: 0.53408968
# epoch: 12 -> Accuracy: 86.01%, Loss: 0.40158349 ---------------- Val_Acc: 81.10%, Val_Loss: 0.52147365
# epoch: 13 -> Accuracy: 86.86%, Loss: 0.37782165 ---------------- Val_Acc: 81.60%, Val_Loss: 0.51172441
# epoch: 14 -> Accuracy: 87.72%, Loss: 0.35693237 ---------------- Val_Acc: 82.00%, Val_Loss: 0.50423890
# epoch: 15 -> Accuracy: 88.48%, Loss: 0.33818564 ---------------- Val_Acc: 82.30%, Val_Loss: 0.49861789
# epoch: 16 -> Accuracy: 89.19%, Loss: 0.32116157 ---------------- Val_Acc: 82.60%, Val_Loss: 0.49431217
# epoch: 17 -> Accuracy: 89.73%, Loss: 0.30547592 ---------------- Val_Acc: 82.60%, Val_Loss: 0.49118552
# epoch: 18 -> Accuracy: 90.27%, Loss: 0.29088047 ---------------- Val_Acc: 82.90%, Val_Loss: 0.48894927
# epoch: 19 -> Accuracy: 90.72%, Loss: 0.27718210 ---------------- Val_Acc: 83.30%, Val_Loss: 0.48762906
# epoch: 20 -> Accuracy: 91.32%, Loss: 0.26424220 ---------------- Val_Acc: 83.30%, Val_Loss: 0.48699650
# epoch: 21 -> Accuracy: 91.91%, Loss: 0.25192180 ---------------- Val_Acc: 83.40%, Val_Loss: 0.48713571
# epoch: 22 -> Accuracy: 92.30%, Loss: 0.24016736 ---------------- Val_Acc: 83.50%, Val_Loss: 0.48782748
# epoch: 23 -> Accuracy: 92.74%, Loss: 0.22884880 ---------------- Val_Acc: 83.50%, Val_Loss: 0.48910001
# epoch: 24 -> Accuracy: 93.18%, Loss: 0.21793401 ---------------- Val_Acc: 83.50%, Val_Loss: 0.49086195
# epoch: 25 -> Accuracy: 93.55%, Loss: 0.20737520 ---------------- Val_Acc: 83.60%, Val_Loss: 0.49309677
# epoch: 26 -> Accuracy: 93.98%, Loss: 0.19714831 ---------------- Val_Acc: 83.70%, Val_Loss: 0.49579006
# epoch: 27 -> Accuracy: 94.33%, Loss: 0.18721680 ---------------- Val_Acc: 84.00%, Val_Loss: 0.49889317
# epoch: 28 -> Accuracy: 94.76%, Loss: 0.17757624 ---------------- Val_Acc: 83.70%, Val_Loss: 0.50258130
# epoch: 29 -> Accuracy: 95.12%, Loss: 0.16816184 ---------------- Val_Acc: 83.50%, Val_Loss: 0.50663364
# epoch: 30 -> Accuracy: 95.45%, Loss: 0.15903215 ---------------- Val_Acc: 83.70%, Val_Loss: 0.51114500
# epoch: 31 -> Accuracy: 95.81%, Loss: 0.15013924 ---------------- Val_Acc: 83.70%, Val_Loss: 0.51610631
# epoch: 32 -> Accuracy: 96.18%, Loss: 0.14149450 ---------------- Val_Acc: 83.40%, Val_Loss: 0.52138478
# epoch: 33 -> Accuracy: 96.50%, Loss: 0.13312532 ---------------- Val_Acc: 83.30%, Val_Loss: 0.52721429
# epoch: 34 -> Accuracy: 96.89%, Loss: 0.12501572 ---------------- Val_Acc: 83.30%, Val_Loss: 0.53330278
# epoch: 35 -> Accuracy: 97.16%, Loss: 0.11716371 ---------------- Val_Acc: 83.20%, Val_Loss: 0.53974611
# epoch: 36 -> Accuracy: 97.52%, Loss: 0.10956585 ---------------- Val_Acc: 83.20%, Val_Loss: 0.54663193
# epoch: 37 -> Accuracy: 97.85%, Loss: 0.10226487 ---------------- Val_Acc: 83.50%, Val_Loss: 0.55388987
# epoch: 38 -> Accuracy: 98.06%, Loss: 0.09518999 ---------------- Val_Acc: 83.50%, Val_Loss: 0.56153178
# epoch: 39 -> Accuracy: 98.30%, Loss: 0.08842304 ---------------- Val_Acc: 83.60%, Val_Loss: 0.56956929
# epoch: 40 -> Accuracy: 98.39%, Loss: 0.08197650 ---------------- Val_Acc: 83.50%, Val_Loss: 0.57794750
# Training time in second: 219.22865637199993

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# # Model Selection
# Hyperparameters are the parameters of the learning method itself which we have to specify a priori, i.e., before model fitting. In contrast, model parameters are parameters which arise as a result of the fit (the network weights). The aim of model selection is selecting the best hyperparameters for our deep network. Finding the right hyperparameters for a model can be crucial for the model performance on given data. For istance lets consider our model trained by using different values for the learning rate:

# %%
learning_rates = [1e-5, 1e-4, 1e-3]

# %%
stack = []
for lr in learning_rates:
  print(f"Learning Rate: {lr}")
  model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[128, 64]).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr=lr)
  stack.append(train(model, optimizer, dataloader_training, dataloader_validation, EPOCHS=15))
  print("-"*50)
# Out:
# Learning Rate: 1e-05
# epoch: 1 -> Accuracy: 28.07%, Loss: 1.39126384 ---------------- Val_Acc: 30.10%, Val_Loss: 1.39249551
# epoch: 2 -> Accuracy: 28.82%, Loss: 1.38567972 ---------------- Val_Acc: 30.60%, Val_Loss: 1.38742208
# epoch: 3 -> Accuracy: 29.61%, Loss: 1.38048458 ---------------- Val_Acc: 31.30%, Val_Loss: 1.38258255
# epoch: 4 -> Accuracy: 30.49%, Loss: 1.37551677 ---------------- Val_Acc: 32.10%, Val_Loss: 1.37793672
# epoch: 5 -> Accuracy: 31.33%, Loss: 1.37073171 ---------------- Val_Acc: 33.10%, Val_Loss: 1.37345433
# epoch: 6 -> Accuracy: 32.46%, Loss: 1.36609983 ---------------- Val_Acc: 34.30%, Val_Loss: 1.36910951
# epoch: 7 -> Accuracy: 33.34%, Loss: 1.36158884 ---------------- Val_Acc: 34.60%, Val_Loss: 1.36484718
# epoch: 8 -> Accuracy: 34.19%, Loss: 1.35715830 ---------------- Val_Acc: 35.40%, Val_Loss: 1.36065722
# epoch: 9 -> Accuracy: 35.25%, Loss: 1.35277915 ---------------- Val_Acc: 36.50%, Val_Loss: 1.35651398
# epoch: 10 -> Accuracy: 36.22%, Loss: 1.34843338 ---------------- Val_Acc: 36.80%, Val_Loss: 1.35239983
# epoch: 11 -> Accuracy: 37.23%, Loss: 1.34409952 ---------------- Val_Acc: 37.60%, Val_Loss: 1.34828675
# epoch: 12 -> Accuracy: 38.63%, Loss: 1.33976221 ---------------- Val_Acc: 39.00%, Val_Loss: 1.34416223
# epoch: 13 -> Accuracy: 39.59%, Loss: 1.33540797 ---------------- Val_Acc: 39.80%, Val_Loss: 1.34001291
# epoch: 14 -> Accuracy: 40.76%, Loss: 1.33100796 ---------------- Val_Acc: 41.10%, Val_Loss: 1.33582497
# epoch: 15 -> Accuracy: 41.93%, Loss: 1.32654989 ---------------- Val_Acc: 42.30%, Val_Loss: 1.33157909
# --------------------------------------------------
# Learning Rate: 0.0001
# epoch: 1 -> Accuracy: 30.27%, Loss: 1.36404610 ---------------- Val_Acc: 33.90%, Val_Loss: 1.34735012
# epoch: 2 -> Accuracy: 39.53%, Loss: 1.32263207 ---------------- Val_Acc: 42.10%, Val_Loss: 1.30734253
# epoch: 3 -> Accuracy: 48.12%, Loss: 1.27508461 ---------------- Val_Acc: 50.80%, Val_Loss: 1.25704372
# epoch: 4 -> Accuracy: 55.06%, Loss: 1.21465373 ---------------- Val_Acc: 56.40%, Val_Loss: 1.19246912
# epoch: 5 -> Accuracy: 61.51%, Loss: 1.13836706 ---------------- Val_Acc: 62.60%, Val_Loss: 1.11143506
# epoch: 6 -> Accuracy: 66.75%, Loss: 1.04706049 ---------------- Val_Acc: 67.70%, Val_Loss: 1.01839566
# epoch: 7 -> Accuracy: 71.20%, Loss: 0.94810957 ---------------- Val_Acc: 72.40%, Val_Loss: 0.92324513
# epoch: 8 -> Accuracy: 74.69%, Loss: 0.85189193 ---------------- Val_Acc: 75.20%, Val_Loss: 0.83602577
# epoch: 9 -> Accuracy: 77.32%, Loss: 0.76543254 ---------------- Val_Acc: 77.20%, Val_Loss: 0.76221102
# epoch: 10 -> Accuracy: 79.14%, Loss: 0.69180900 ---------------- Val_Acc: 78.50%, Val_Loss: 0.70230258
# epoch: 11 -> Accuracy: 80.56%, Loss: 0.63107026 ---------------- Val_Acc: 79.20%, Val_Loss: 0.65463209
# epoch: 12 -> Accuracy: 81.60%, Loss: 0.58174700 ---------------- Val_Acc: 80.30%, Val_Loss: 0.61743450
# epoch: 13 -> Accuracy: 82.58%, Loss: 0.54164100 ---------------- Val_Acc: 80.80%, Val_Loss: 0.58823085
# epoch: 14 -> Accuracy: 83.45%, Loss: 0.50882149 ---------------- Val_Acc: 80.60%, Val_Loss: 0.56519037
# epoch: 15 -> Accuracy: 83.92%, Loss: 0.48157683 ---------------- Val_Acc: 81.30%, Val_Loss: 0.54681170
# --------------------------------------------------
# Learning Rate: 0.001
# epoch: 1 -> Accuracy: 55.24%, Loss: 1.16292751 ---------------- Val_Acc: 73.30%, Val_Loss: 0.82606375
# epoch: 2 -> Accuracy: 80.41%, Loss: 0.57496250 ---------------- Val_Acc: 81.20%, Val_Loss: 0.51088786
# epoch: 3 -> Accuracy: 86.14%, Loss: 0.39297375 ---------------- Val_Acc: 83.20%, Val_Loss: 0.47149855
# epoch: 4 -> Accuracy: 88.65%, Loss: 0.32065642 ---------------- Val_Acc: 83.30%, Val_Loss: 0.46497923
# epoch: 5 -> Accuracy: 90.65%, Loss: 0.27180016 ---------------- Val_Acc: 83.30%, Val_Loss: 0.46906015
# epoch: 6 -> Accuracy: 92.28%, Loss: 0.23097487 ---------------- Val_Acc: 83.40%, Val_Loss: 0.47902220
# epoch: 7 -> Accuracy: 93.90%, Loss: 0.19375491 ---------------- Val_Acc: 83.10%, Val_Loss: 0.49621797
# epoch: 8 -> Accuracy: 95.46%, Loss: 0.15868936 ---------------- Val_Acc: 82.60%, Val_Loss: 0.52171177
# epoch: 9 -> Accuracy: 96.63%, Loss: 0.12671404 ---------------- Val_Acc: 82.80%, Val_Loss: 0.55420530
# epoch: 10 -> Accuracy: 97.90%, Loss: 0.09896287 ---------------- Val_Acc: 82.60%, Val_Loss: 0.59572637
# epoch: 11 -> Accuracy: 98.63%, Loss: 0.07605982 ---------------- Val_Acc: 82.20%, Val_Loss: 0.64096618
# epoch: 12 -> Accuracy: 99.16%, Loss: 0.05845967 ---------------- Val_Acc: 82.30%, Val_Loss: 0.68435645
# epoch: 13 -> Accuracy: 99.49%, Loss: 0.04593451 ---------------- Val_Acc: 82.60%, Val_Loss: 0.71145487
# epoch: 14 -> Accuracy: 99.61%, Loss: 0.03826211 ---------------- Val_Acc: 82.60%, Val_Loss: 0.72971243
# epoch: 15 -> Accuracy: 99.66%, Loss: 0.03480678 ---------------- Val_Acc: 83.00%, Val_Loss: 0.78688020
# --------------------------------------------------

# %%
# Let's plot the results
for idx, el in enumerate(stack):
  print(f"Learning Rate: {learning_rates[idx]}")
  plot_learning_acc_and_loss(*el)
# Out:
# Learning Rate: 1e-05
# Learning Rate: 0.0001
# Learning Rate: 0.001

# %% [markdown]
# # Exercise 2.5: Grid Search
#
# Since a deep net has many hyperparameters, in order to find the best ones, we have to consider different possible combinations of values for each hyper-parameter. One common method to perform this complex task is Grid-Search.
# Given a set of values for each hyper-parameter, Grid-Search will build a model on each parameter combination possible. It iterates through every parameter combination and stores a model for each combination. Finally, the model that obtained the best result on the validation set will be selected.
#
# In order to perfrom Grid-Search we will use the `GridSearchCV` class from `scikit-learn`, together with some classes from the `skorch` package which allows to use PyTorch models with `scikit-learn`.

# %%
model = NeuralNetClassifier(
    module=FeedforwardNetwork,
    criterion=torch.nn.CrossEntropyLoss,
    optimizer=torch.optim.Adam,
    max_epochs=2)

# we need to adapt PyTorch Dataset to work with Scikit-Learn GridSearchCV
# we use the SliceDataset class from skorch package for this purpose
X_slice = SliceDataset(train_dataset, idx=1)
y_slice = SliceDataset(train_dataset, idx=0)

# %% [markdown]
# ## **[TO COMPLETE]**: Define hyperparameters grid

# %% [markdown]
# Let's define the lists of hyper-parameters' values. Also in this case, we use dictionaries of very limited size and hyperparameters, but in a real-world scenario a reasonable amount of possible values should be considered (and there are many other approacehs besisdes Grid-Search).

# %% [markdown]
# `%STARTCODE`

# %%
params = {
    'lr': [0.01, 0.1], #[TO COMPLETE]
    'module__input_dim': [len(vocab)], #[TO COMPLETE]
    'module__num_classes': [len(set([label for (label , text) in train_data]))],#[TO COMPLETE]
    'module__hidden_layers_dim':[[64,64],[128,128]], #[TO COMPLETE]
    }

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# Now you can use `sklearn`'s `GridSearchCV` to search the hyperparameter space of the `NeuralNetClassifier`:

# %%
n_jobs = multiprocessing.cpu_count()-1
gs = GridSearchCV(model, params, n_jobs=n_jobs)

# %%
outputs = gs.fit(X_slice, y_slice)
# Out:
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.7102       0.8419        0.4857  8.9826
#       2        0.3088       0.8438        0.4983  7.1108
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.7289       0.8056        0.5064  8.9315
#       2        0.3208       0.7969        0.6057  8.9329
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.7206       0.8119        0.5236  7.1925
#       2        0.3161       0.8194        0.5402  8.9856
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.7111       0.8275        0.4788  9.0719
#       2        0.3238       0.8181        0.5076  7.2434
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.7341       0.8187        0.5012  7.1855
#       2        0.3239       0.8269        0.5138  9.0715
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.6973       0.8363        0.4837  8.8849
#       2        0.2788       0.8350        0.5329  7.3676
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.7199       0.8150        0.5098  8.9664
#       2        0.2748       0.7994        0.5955  8.6216
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.6836       0.8187        0.5070  7.1835
#       2        0.2785       0.7950        0.5923  8.9421
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.7016       0.8237        0.4753  8.9839
#       2        0.2877       0.8231        0.5347  7.2493
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.7035       0.8294        0.4816  7.2847
#       2        0.2739       0.8219        0.5607  8.9551
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.0430       0.7338        0.7140  8.9007
#       2        0.6068       0.7725        0.6742  7.2189
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.2036       0.7506        0.7149  8.9906
#       2        0.5796       0.7950        0.5855  8.5012
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.9964       0.7538        0.6447  7.1278
#       2        0.5169       0.8063        0.6684  8.9443
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.0807       0.7594        0.6464  10.3049
#       2        0.5068       0.7881        0.6113  11.1768
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.9616       0.7731        0.6387  7.1288
#       2        0.5005       0.8137        0.5589  8.9455
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        2.0128       0.5894        1.1112  9.0454
#       2        0.7911       0.7519        0.7180  7.2578
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        2.0089       0.4956        1.1626  9.1188
#       2        1.0441       0.5925        1.0021  9.0230
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.8264       0.5906        1.0247  15.1449
#       2        0.8127       0.7488        0.7503  11.4442
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.7704       0.7288        0.7312  8.9977
#       2        0.5442       0.7900        0.6042  7.1424
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.7976       0.5206        1.0392  8.9143
#       2        0.7399       0.7675        0.6682  9.0743
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        0.6616       0.8315        0.4739  10.7026
#       2        0.3116       0.8280        0.5293  9.8775

# %% [markdown]
# ## **[TO COMPLETE]**: Visualize results
# Print the best hyper-parameters and the performances on the best model on the test set:

# %% [markdown]
# `%STARTCODE`

# %%
print("best score: {:.3f}, best params: {}".format(gs.best_score_, gs.best_params_))
#[TO COMPLETE]
# Out:
# best score: 0.820, best params: {'lr': 0.01, 'module__hidden_layers_dim': [64, 64], 'module__input_dim': 1000, 'module__num_classes': 4}

# %%
# Test the model
X_test = SliceDataset(test_dataset , idx = 1)
y_test = SliceDataset(test_dataset , idx = 0)
print('The accuracy is {}'.format(gs.best_estimator_.score(X_test ,y_test )))
#[TO COMPLETE]
# Out:
# The accuracy is 0.823

# %% [markdown]
# `%ENDCODE`
